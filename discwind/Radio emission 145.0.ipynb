# %%
import discAnalysisPolar as dap
# %pylab inline
# Out:
# /localhome/pytd/opt/discAnalysisPolar.py:112: RuntimeWarning: invalid value encountered in multiply
#   self.Z*=unitLength
# /localhome/pytd/opt/discAnalysisPolar.py:167: RuntimeWarning: invalid value encountered in true_divide
#   ans=(self.p1()*self.p1()+self.p2()*self.p2())/self.rho()/2
# /localhome/pytd/opt/discAnalysisPolar.py:160: RuntimeWarning: invalid value encountered in less
#   self._pg[self._pg<0.01*self.ke()]=0.01*self.ke()[self._pg<0.01*self.ke()]
# /localhome/pytd/opt/discAnalysisPolar.py:161: RuntimeWarning: invalid value encountered in less
#   self._U1[self._pg<0.01*self.ke()]*=sqrt(0.99) # if pressure is < 0.01 ke floor it to that and remove it from the ke
# /localhome/pytd/opt/discAnalysisPolar.py:162: RuntimeWarning: invalid value encountered in less
#   self._U2[self._pg<0.01*self.ke()]*=sqrt(0.99) # ie mach number of the gas is limited to 100
# Populating the interactive namespace from numpy and matplotlib
# ...

# %%
inner=dap.disc('in_1450', unitLength=145*dap.r_sol, doLerp=1, shape=(2000,1000))
outer=dap.disc('LD_1450', unitLength=145*dap.r_sol, doLerp=1, shape=(2000,1000))

# %%
import utils as ut
reload (ut)
# Out:
# <module 'utils' from '/localhome/pytd/opt/utils.pyc'>

# %%
ut.niceim(inner.rho().T, log=1)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fbf7bbf9170>

# %%
ut.niceim(outer.rho().T, log=1)

# %%
merged=dap.mergeDiscs(inner,outer)
ut.niceim(merged.rho().T, log=1)

# %%
ut.niceim((merged.rho()*merged.ionisation(bal=0)).T, log=1)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fde9d968ab8>

# %%
import FreeFree as ff
reload(ff)
# Out:
# importing integration routine from /home/student13/pytd/home.linux/.local/lib/python2.7/site-packages/FreeFree/integ.so
# <module 'FreeFree' from '/home/student13/pytd/home.linux/.local/lib/python2.7/site-packages/FreeFree/__init__.pyc'>

# %%
radio=ff.freeFree(merged.ionisedRhoCube((300,300,200), aa=1)/1000.0, 50000.0*ones((300,300,200), dtype=float), merged.r().max()*100*2/300)
# Out:
# 1.44365549964e+13

# %%
radio.rotatecube(60)

# %%
im=radio.rayTrace(5e9)
# Out:
# calculating taus

# %%
ut.niceim(radio.rho.sum(-1), log=1)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fde9c70b8c0>

# %%
ut.niceim(radio.dt.sum(-1))
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7fde9fe856c8>

# %%
im.sum()
# Out:
# 2.6109687733646764e-08

# %%
merged.massflux()
# Out:
# /localhome/pytd/opt/discAnalysisPolar.py:242: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.ke()+self.pg())<(centralMass*cns.gravitational_constant*self.rho()/self.r())
# 2.546689332097308e-10
