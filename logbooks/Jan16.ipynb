# %% [markdown]
# Found a bug in the radiation pressure for the 2D cartesian hydrodynamics in torus. It was using the the spherical r unit vector to give the cylicndrical component of the force (i.e. $\hat r \cdot f$ rather than $\hat R \cdot f$) and so was mixing the z component of the radiation pressure into the R component which gave funny looking radative driving from a finite size source

# %%
from IPython.display import Image

# %%
Image(filename='/Users/tdouglas/withCAK.png')

# %% [markdown]
# This has now been fixed in the main branch

# %%
Image(filename='/Users/tdouglas/withCAKfixed.png')

# %% [markdown]
# Im now looking into the 2D hydrodynamics module as Tim says theres some trouble witht the viscosity for it, in particular it's not replicating the spreading disc as it should.
#
# A thin ring should spread out as a gaussian over time and there is an analyitical solution to how it should evolve

# %% [markdown]
# Talk about stuff trying different viscous methods, constructing face velocities, higher order differentiation and constructing directly 2nd velocity differentials. See mpeg movies in this folder for comparison of 3rd order and face velocites as they evolve
